# %% [markdown]
# Build a regression model.

# %%
#Import packages
import pandas as pd
import numpy as np
import statsmodels.api as sm

# %%
#Import data from previous CSV
bikesLA_data = pd.read_csv('data/final_data.csv')
bikesLA_data
# Out:
#                               name price  rating  review_count  \
# 0     10 Speed Coffee-Santa Monica    $$     0.0           0.0
# 1                       Bagel Nosh    $$     0.0           0.0
# 2           DK's Donuts and Bakery    $$     0.0           0.0
# 3                Goodboybob Coffee    $$     0.0           0.0
# 4                La Monarca Bakery    $$     0.0           0.0
# ...                            ...   ...     ...           ...
# 2195   Sabor Colombiano Restaurant    $$     0.0           0.0
# 2196       Seoul Garden Restaurant    $$     4.0         575.0
# 2197                       Shabuya    $$     4.0         865.0
# 2198                     Starbucks    $$     0.0           0.0
# 2199         Oceans Cafe and Grill    $$     4.5          55.0
#
#                       uid  bk_station_distance_y  latitude  longitude  \
# 0     bcycle_lametro_4216                    585  34.02339 -118.47964
# ...

# %%
#Show basic information from dataframe
bikesLA_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   name                   2200 non-null   object
#  1   price                  2200 non-null   object
#  2   rating                 2200 non-null   float64
#  3   review_count           2200 non-null   float64
#  4   uid                    2200 non-null   object
#  5   bk_station_distance_y  2200 non-null   int64
#  6   latitude               2200 non-null   float64
#  7   longitude              2200 non-null   float64
#  8   free_bikes             2200 non-null   int64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 154.8+ KB

# %%
#Decided to change price information to add value to the model.
bikesLA_data['price']= np.where(bikesLA_data['price'] == '$',0,bikesLA_data['price'])
bikesLA_data['price']= np.where(bikesLA_data['price'] == '$$',1,bikesLA_data['price'])
bikesLA_data['price']= np.where(bikesLA_data['price'] == '$$$',2,bikesLA_data['price'])
bikesLA_data['price']= np.where(bikesLA_data['price'] == '$$$$',3,bikesLA_data['price'])

bikesLA_data['price'] = pd.to_numeric(bikesLA_data['price'])
bikesLA_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   name                   2200 non-null   object
#  1   price                  2200 non-null   int64
#  2   rating                 2200 non-null   float64
#  3   review_count           2200 non-null   float64
#  4   uid                    2200 non-null   object
#  5   bk_station_distance_y  2200 non-null   int64
#  6   latitude               2200 non-null   float64
#  7   longitude              2200 non-null   float64
#  8   free_bikes             2200 non-null   int64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 154.8+ KB

# %%
#Remove columns that do not contribute to the model
df_stats = bikesLA_data.drop(columns=['latitude','longitude','uid','name'])

# %%
#Basic information data
df_stats.describe()
# Out:
#              price       rating  review_count  bk_station_distance_y  \
# count  2200.000000  2200.000000   2200.000000            2200.000000
# mean      1.000000     1.330682    597.094091             458.487727
# std       0.326209     1.923642   1821.553228             269.360293
# min       0.000000     0.000000      0.000000               6.000000
# 25%       1.000000     0.000000      0.000000             238.000000
# 50%       1.000000     0.000000      0.000000             430.000000
# 75%       1.000000     4.000000    552.000000             666.250000
# max       3.000000     5.000000  18069.000000            1015.000000
#
#         free_bikes
# count  2200.000000
# mean      6.828636
# std       3.013113
# min       0.000000
# 25%       5.000000
# 50%       6.000000
# 75%       9.000000
# max      17.000000

# %% [markdown]
# Provide model output and an interpretation of the results.

# %%
#run full model
y = df_stats['free_bikes']
X = df_stats.drop('free_bikes', axis=1)
X = sm.add_constant(X) #adds a column of 1's so the model will contain an intercept

model = sm.OLS(y, X)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             free_bikes   R-squared:                       0.014
# Model:                            OLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     7.727
# Date:                Sun, 26 Feb 2023   Prob (F-statistic):           3.51e-06
# Time:                        17:23:21   Log-Likelihood:                -5532.3
# No. Observations:                2200   AIC:                         1.107e+04
# Df Residuals:                    2195   BIC:                         1.110e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     7.3614      0.240     30.685      0.000       6.891       7.832
# ...

# %% [markdown]
# > - After reviewing the data from Foursquare and Yelp against the city bike dataset; I notice that the values do not have a high correlation. For example the quantity of available bikes is not related with any other variable.
# > - Even after including the price variable and review counts there is not strong dependance of the variables.
# > - The model requires more information to define any conclusion. It is hard to determine if the reviews are related to people using city bikes.

# %% [markdown]
# # Stretch

# %% [markdown]
# How can you turn the regression model into a classification model?
